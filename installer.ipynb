# %%
# %pip install pytesseract tesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl.metadata (11 kB)
# Collecting tesseract
#   Downloading tesseract-0.1.3.tar.gz (45.6 MB)
#      ---------------------------------------- 0.0/45.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/45.6 MB ? eta -:--:--
#      --------------------------------------- 0.1/45.6 MB 825.8 kB/s eta 0:00:56
#      ---------------------------------------- 0.1/45.6 MB 1.1 MB/s eta 0:00:44
#      ---------------------------------------- 0.1/45.6 MB 1.1 MB/s eta 0:00:44
#      --------------------------------------- 0.2/45.6 MB 958.4 kB/s eta 0:00:48
#      ---------------------------------------- 0.3/45.6 MB 1.1 MB/s eta 0:00:44
#      ---------------------------------------- 0.4/45.6 MB 1.3 MB/s eta 0:00:36
#      ---------------------------------------- 0.4/45.6 MB 1.3 MB/s eta 0:00:36
#      ---------------------------------------- 0.4/45.6 MB 1.3 MB/s eta 0:00:36
#      ---------------------------------------- 0.6/45.6 MB 1.3 MB/s eta 0:00:34
#       --------------------------------------- 0.7/45.6 MB 1.4 MB/s eta 0:00:32
#       --------------------------------------- 0.9/45.6 MB 1.7 MB/s eta 0:00:27
#       --------------------------------------- 0.9/45.6 MB 1.7 MB/s eta 0:00:27
#       --------------------------------------- 0.9/45.6 MB 1.7 MB/s eta 0:00:27
#      - -------------------------------------- 1.2/45.6 MB 1.7 MB/s eta 0:00:27
#      - -------------------------------------- 1.2/45.6 MB 1.7 MB/s eta 0:00:27
#      - -------------------------------------- 1.3/45.6 MB 1.7 MB/s eta 0:00:26
#      - -------------------------------------- 1.3/45.6 MB 1.7 MB/s eta 0:00:26
#      - -------------------------------------- 1.5/45.6 MB 1.8 MB/s eta 0:00:26
#      - -------------------------------------- 1.5/45.6 MB 1.7 MB/s eta 0:00:27
#      - -------------------------------------- 1.7/45.6 MB 1.7 MB/s eta 0:00:26
#      - -------------------------------------- 1.7/45.6 MB 1.7 MB/s eta 0:00:26
#      - -------------------------------------- 1.7/45.6 MB 1.7 MB/s eta 0:00:26
#      - -------------------------------------- 1.9/45.6 MB 1.8 MB/s eta 0:00:25
#      - -------------------------------------- 1.9/45.6 MB 1.8 MB/s eta 0:00:25
#      - -------------------------------------- 2.1/45.6 MB 1.8 MB/s eta 0:00:24
#      -- ------------------------------------- 2.4/45.6 MB 2.0 MB/s eta 0:00:22
#      -- ------------------------------------- 2.8/45.6 MB 2.1 MB/s eta 0:00:21
#      -- ------------------------------------- 2.9/45.6 MB 2.2 MB/s eta 0:00:20
#      -- ------------------------------------- 3.2/45.6 MB 2.3 MB/s eta 0:00:19
#      --- ------------------------------------ 3.4/45.6 MB 2.4 MB/s eta 0:00:18
#      --- ------------------------------------ 3.5/45.6 MB 2.4 MB/s eta 0:00:18
#      --- ------------------------------------ 3.9/45.6 MB 2.6 MB/s eta 0:00:17
#      --- ------------------------------------ 4.3/45.6 MB 2.7 MB/s eta 0:00:16
#      ---- ----------------------------------- 4.8/45.6 MB 3.0 MB/s eta 0:00:14
#      ---- ----------------------------------- 5.4/45.6 MB 3.2 MB/s eta 0:00:13
#      ----- ---------------------------------- 6.0/45.6 MB 3.5 MB/s eta 0:00:12
#      ----- ---------------------------------- 6.5/45.6 MB 3.6 MB/s eta 0:00:11
#      ----- ---------------------------------- 6
2 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 33.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 27.8 MB/s eta 0:00:00
# Building wheels for collected packages: tesseract
#   Building wheel for tesseract (pyproject.toml): started
#   Building wheel for tesseract (pyproject.toml): finished with status 'done'
#   Created wheel for tesseract: filename=tesseract-0.1.3-py3-none-any.whl size=45562568 sha256=92253d48dab2665d28f5c229f813c2ced2b063a3bf91dc7cbd127de16a42bfc4
#   Stored in directory: c:\users\khanw\appdata\local\pip\cache\wheels\13\1f\8e\2d6c0e358fd6d01ca80ecd9185a374bcda35879f4fec727242
# Successfully built tesseract
# Installing collected packages: tesseract, Pillow, pytesseract
# Successfully installed Pillow-10.2.0 pytesseract-0.3.10 tesseract-0.1.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script pytesseract.exe is installed in 'c:\Users\khanw\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# %pip install opencv-python
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting opencv-python
#   Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting numpy>=1.21.2 (from opencv-python)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 806.3 kB/s eta 0:00:00
# Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.6 MB 2.6 MB/s eta 0:00:15
#     --------------------------------------- 0.7/38.6 MB 7.1 MB/s eta 0:00:06
#    - -------------------------------------- 1.9/38.6 MB 13.4 MB/s eta 0:00:03
#    --- ------------------------------------ 3.7/38.6 MB 19.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 5.4/38.6 MB 23.1 MB/s eta 0:00:02
#    ------- -------------------------------- 7.3/38.6 MB 25.9 MB/s eta 0:00:02
#    --------- ------------------------------ 9.5/38.6 MB 28.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 11.5/38.6 MB 38.6 MB/s eta 0:00:01
#    ------------- -------------------------- 13.4/38.6 MB 43.7 MB/s eta 0:00:01
#    -------------- ------------------------- 13.8/38.6 MB 43.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 16.8/38.6 MB 38.5 MB/s eta 0:00:01
#    ------------------ --------------------- 18.3/38.6 MB 38.5 MB/s eta 0:00:01
#    -------------------- ------------------- 19.7/38.6 MB 36.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 21.4/38.6 MB 34.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 23.1/38.6 MB 34.4 MB/s eta 0:00:01
#    ------------------------- -------------- 24.9/38.6 MB 38.6 MB/s eta 0:00:01
#    --------------------------- ------------ 26.6/38.6 MB 34.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.5/38.6 MB 36.4 MB/s eta 0:00:01
#    ------------------------------- -------- 30.6/38.6 MB 38.5 MB/s eta 0:00:01
#    --------------------------------- ------ 32.1/38.6 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.6/38.6 MB 36.3 MB/s eta 0:00:01
#    ------------------------------------ --- 35.1/38.6 MB 36.4 MB/s eta 0:00:01
#    ------------------------------------- -- 36.6/38.6 MB 36.4 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 14.9 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.8/15.5 MB 37.5 MB/s eta 0:00:01
#    --------- ------------------------------ 3.6/15.5 MB 39.1 MB/s eta 0:00:01
#    ------------ --------------------------- 4.9/15.5 MB 39.3 MB/s eta 0:00:01
#    --------------- ------------------------ 6.2/15.5 MB 33.0 MB/s eta 0:00:01
#    ------------------- -------------------- 7.6/15.5 MB 32.4 MB/s eta 0:00:01
#    ------------------------ --------------- 9.4/15.5 MB 33.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.0/15.5 MB 32.7 MB/s eta 0:00:01
#    ------------------------------ --------- 12.0/15.5 MB 31.2 MB/s eta 0:00:01
#    --------------------------------- ------ 13.0/15.5 MB 28.4 MB/s eta 0:00:01
#    -------------------------------------- - 14.8/15.5 MB 29.8 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 18.2 MB/s eta 0:00:00
# Installing collected packages: numpy, opencv-python
# Successfully installed numpy-1.26.4 opencv-python-4.9.0.80
#   WARNING: The script f2py.exe is installed in 'c:\Users\khanw\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# %pip install tesseract
# Out:
# Requirement already satisfied: tesseract in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (0.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.1.12-py3-none-any.whl.metadata (13 kB)
# Collecting PyYAML>=5.3 (from langchain)
#   Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.28-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.9.3-cp312-cp312-win_amd64.whl.metadata (7.6 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl.metadata (25 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-community<0.1,>=0.0.28 (from langchain)
#   Downloading langchain_community-0.0.28-py3-none-any.whl.metadata (8.3 kB)
# Collecting langchain-core<0.2.0,>=0.1.31 (from langchain)
#   Downloading langchain_core-0.1.32-py3-none-any.whl.metadata (6.0 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain)
#   Downloading langchain_text_splitters-0.0.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.27-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain) (1.26.4)
# Collecting pydantic<3,>=1 (from langchain)
#   Downloading pydantic-2.6.4-py3-none-any.whl.metadata (85 kB)
#      ---------------------------------------- 0.0/85.1 kB ? eta -:--:--
#      ---------------------------------------- 85.1/85.1 kB 1.6 MB/s eta 0:00:00
# Collecting requests<3,>=2 (from langchain)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.4.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.0.5-cp312-cp312-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.9.4-cp312-cp312-win_amd64.whl.metadata (32 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.21.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting anyio<5,>=3 (from langchain-core<0.2.0,>=0.1.31->langchain)
#   Downloading anyio-4.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.31->langchain)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.9.15-cp312-none-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 50.7/50.7 kB ? eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1->langchain)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.16.3 (from pydantic<3,>=1->langchain)
#   Downloading pydantic_core-2.16.3-cp312-none-win_amd64.whl.metadata (6.6 kB)
# Collecting typing-extensions>=4.6.1 (from pydantic<3,>=1->langchain)
#   Downloading typing_extensions-4.10.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2->langchain)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2->langchain)
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langchain)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2->langchain)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.0.3-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting sniffio>=1.1 (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.31->langchain)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain-0.1.12-py3-none-any.whl (809 kB)
#    ---------------------------------------- 0.0/809.1 kB ? eta -:--:--
#    ------------------ --------------------- 368.6/809.1 kB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 809.1/809.1 kB 7.3 MB/s eta 0:00:00
# Downloading aiohttp-3.9.3-cp312-cp312-win_amd64.whl (363 kB)
#    ---------------------------------------- 0.0/363.4 kB ? eta -:--:--
#    --------------------------------------- 363.4/363.4 kB 22.1 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_community-0.0.28-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ------------------- -------------------- 0.9/1.8 MB 18.3 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 22.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 18.9 MB/s eta 0:00:00
# Downloading langchain_core-0.1.32-py3-none-any.whl (260 kB)
#    ---------------------------------------- 0.0/260.9 kB ? eta -:--:--
#    ---------------------------------------- 260.9/260.9 kB 7.8 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Downloading langsmith-0.1.27-py3-none-any.whl (68 kB)
#    ---------------------------------------- 0.0/68.0 kB ? eta -:--:--
#    ---------------------------------------- 68.0/68.0 kB 3.6 MB/s eta 0:00:00
# Downloading pydantic-2.6.4-py3-none-any.whl (394 kB)
#    ---------------------------------------- 0.0/394.9 kB ? eta -:--:--
#    --------------------------------------- 394.9/394.9 kB 24.0 MB/s eta 0:00:00
# Downloading pydantic_core-2.16.3-cp312-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------- ----------- 1.3/1.9 MB 42.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 29.5 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl (138 kB)
#    ---------------------------------------- 0.0/138.7 kB ? eta -:--:--
#    ---------------------------------------- 138.7/138.7 kB 8.0 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB ? eta 0:00:00
# Downloading SQLAlchemy-2.0.28-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------------------------- ---------- 1.5/2.1 MB 48.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 33.3 MB/s eta 0:00:00
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading anyio-4.3.0-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.6 kB ? eta -:--:--
#    ---------------------------------------- 85.6/85.6 kB 5.0 MB/s eta 0:00:00
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.8 kB ? eta -:--:--
#    ---------------------------------------- 163.8/163.8 kB ? eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
#    ---------------------------------------- 0.0/100.4 kB ? eta -:--:--
#    ---------------------------------------- 100.4/100.4 kB 5.6 MB/s eta 0:00:00
# Downloading frozenlist-1.4.1-cp312-cp312-win_amd64.whl (50 kB)
#    ---------------------------------------- 0.0/50.5 kB ? eta -:--:--
#    ---------------------------------------- 50.5/50.5 kB 2.5 MB/s eta 0:00:00
# Downloading greenlet-3.0.3-cp312-cp312-win_amd64.whl (293 kB)
#    ---------------------------------------- 0.0/293.6 kB ? eta -:--:--
#    --------------------------------------- 293.6/293.6 kB 17.7 MB/s eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.6 kB ? eta -:--:--
#    ---------------------------------------- 61.6/61.6 kB 3.2 MB/s eta 0:00:00
# Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Downloading marshmallow-3.21.1-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.4 kB ? eta -:--:--
#    ---------------------------------------- 49.4/49.4 kB ? eta 0:00:00
# Downloading multidict-6.0.5-cp312-cp312-win_amd64.whl (27 kB)
# Downloading orjson-3.9.15-cp312-none-win_amd64.whl (136 kB)
#    ---------------------------------------- 0.0/136.1 kB ? eta -:--:--
#    ---------------------------------------- 136.1/136.1 kB 7.9 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ---------------------------------------- 0.0/53.0 kB ? eta -:--:--
#    ---------------------------------------- 53.0/53.0 kB 2.7 MB/s eta 0:00:00
# Downloading typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.1 kB ? eta -:--:--
#    ---------------------------------------- 121.1/121.1 kB ? eta 0:00:00
# Downloading yarl-1.9.4-cp312-cp312-win_amd64.whl (76 kB)
#    ---------------------------------------- 0.0/76.4 kB ? eta -:--:--
#    ---------------------------------------- 76.4/76.4 kB 4.4 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: urllib3, typing-extensions, tenacity, sniffio, PyYAML, packaging, orjson, mypy-extensions, multidict, jsonpointer, idna, greenlet, frozenlist, charset-normalizer, certifi, attrs, annotated-types, yarl, typing-inspect, SQLAlchemy, requests, pydantic-core, marshmallow, jsonpatch, anyio, aiosignal, pydantic, dataclasses-json, aiohttp, langsmith, langchain-core, langchain-text-splitters, langchain-community, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed PyYAML-6.0.1 SQLAlchemy-2.0.28 aiohttp-3.9.3 aiosignal-1.3.1 annotated-types-0.6.0 anyio-4.3.0 attrs-23.2.0 certifi-2024.2.2 charset-normalizer-3.3.2 dataclasses-json-0.6.4 frozenlist-1.4.1 greenlet-3.0.3 idna-3.6 jsonpatch-1.33 jsonpointer-2.4 langchain-0.1.12 langchain-community-0.0.28 langchain-core-0.1.32 langchain-text-splitters-0.0.1 langsmith-0.1.27 marshmallow-3.21.1 multidict-6.0.5 mypy-extensions-1.0.0 orjson-3.9.15 packaging-23.2 pydantic-2.6.4 pydantic-core-2.16.3 requests-2.31.0 sniffio-1.3.1 tenacity-8.2.3 typing-extensions-4.10.0 typing-inspect-0.9.0 urllib3-2.2.1 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\khanw\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script langsmith.exe is installed in 'c:\Users\khanw\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script langchain-server.exe is installed in 'c:\Users\khanw\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# %pip install langchain-core
# Out:
# Requirement already satisfied: langchain-core in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (0.1.32)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: PyYAML>=5.3 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (6.0.1)
# Requirement already satisfied: anyio<5,>=3 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (4.3.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (0.1.27)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (2.6.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core) (8.2.3)
# Requirement already satisfied: idna>=2.8 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3->langchain-core) (3.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3->langchain-core) (1.3.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1->langchain-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1->langchain-core) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1->langchain-core) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain-core) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain-core) (2024.2.2)

# %%
# %pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.14.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.3.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from openai) (2.6.4)
# Requirement already satisfied: sniffio in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.3.1)
# Collecting tqdm>4 (from openai)
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      --------------------------- ---------- 41.0/57.6 kB 960.0 kB/s eta 0:00:01
#      -------------------------------------- 57.6/57.6 kB 751.5 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.10.0)
# Requirement already satisfied: idna>=2.8 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: certifi in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.4-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Requirement already satisfied: colorama in c:\users\khanw\appdata\roaming\python\python312\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-1.14.1-py3-none-any.whl (257 kB)
#    ---------------------------------------- 0.0/257.5 kB ? eta -:--:--
#    ------------------- -------------------- 122.9/257.5 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 257.5/257.5 kB 3.2 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB 4.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.8 kB ? eta -:--:--
#    ---------------------------------------- 77.8/77.8 kB 4.2 MB/s eta 0:00:00
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB ? eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: tqdm, h11, distro, httpcore, httpx, openai
# Successfully installed distro-1.9.0 h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 openai-1.14.1 tqdm-4.66.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\khanw\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script distro.exe is installed in 'c:\Users\khanw\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'c:\Users\khanw\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script openai.exe is installed in 'c:\Users\khanw\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# %pip install langchain-openai
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-0.0.8-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.27 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-openai) (0.1.32)
# Requirement already satisfied: openai<2.0.0,>=1.10.0 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-openai) (1.14.1)
# Collecting tiktoken<1,>=0.5.2 (from langchain-openai)
#   Downloading tiktoken-0.6.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (6.0.1)
# Requirement already satisfied: anyio<5,>=3 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (4.3.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (0.1.27)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (2.6.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (8.2.3)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (4.10.0)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.5.2->langchain-openai)
#   Downloading regex-2023.12.25-cp312-cp312-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/42.0 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------  41.0/42.0 kB 495.5 kB/s eta 0:00:01
#      -------------------------------------- 42.0/42.0 kB 406.8 kB/s eta 0:00:00
# Requirement already satisfied: idna>=2.8 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.27->langchain-openai) (3.6)
# Requirement already satisfied: certifi in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.27->langchain-openai) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.27->langchain-openai) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.27->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.27->langchain-openai) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain-core<0.2.0,>=0.1.27->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khanw\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain-core<0.2.0,>=0.1.27->langchain-openai) (2.2.1)
# Requirement already satisfied: colorama in c:\users\khanw\appdata\roaming\python\python312\site-packages (from tqdm>4->openai<2.0.0,>=1.10.0->langchain-openai) (0.4.6)
# Downloading langchain_openai-0.0.8-py3-none-any.whl (32 kB)
# Downloading tiktoken-0.6.0-cp312-cp312-win_amd64.whl (798 kB)
#    ---------------------------------------- 0.0/798.3 kB ? eta -:--:--
#    ------ --------------------------------- 122.9/798.3 kB 2.4 MB/s eta 0:00:01
#    --------------------- ------------------ 430.1/798.3 kB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  788.5/798.3 kB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 798.3/798.3 kB 5.6 MB/s eta 0:00:00
# Downloading regex-2023.12.25-cp312-cp312-win_amd64.whl (268 kB)
#    ---------------------------------------- 0.0/268.9 kB ? eta -:--:--
#    --------------------------------------- 268.9/268.9 kB 17.2 MB/s eta 0:00:00
# Installing collected packages: regex, tiktoken, langchain-openai
# Successfully installed langchain-openai-0.0.8 regex-2023.12.25 tiktoken-0.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install FFmpeg
# Out:
# Collecting FFmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: FFmpeg
#   Building wheel for FFmpeg (pyproject.toml): started
#   Building wheel for FFmpeg (pyproject.toml): finished with status 'done'
#   Created wheel for FFmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6090 sha256=b04c55c2831f7ee663d23ba8be2c48e32d83c050826bcd89de56854c6d7930de
#   Stored in directory: c:\users\khanw\appdata\local\pip\cache\wheels\26\21\0c\c26e09dff860a9071683e279445262346e008a9a1d2142c4ad
# Successfully built FFmpeg
# Installing collected packages: FFmpeg
# Successfully installed FFmpeg-1.4
# Note: you may need to restart the kernel to use updated packages.
